# %% [markdown]
# # 1. 전체 흐름

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 2. Role

# %% [markdown]
# ## 2.1 Non role

# %% [markdown]
# ### 2.1.1 현재 프로젝트의 권한 확인

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2.1.2 앱 확인 및 외부 링크 찾기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# - All drive : https://vertexaisearch.cloud.google.com/home/cid/0489ad53-6483-429d-bf46-16a03e59c33b
# - Non auth : https://vertexaisearch.cloud.google.com/home/cid/fbd262c9-c5ad-4352-a594-0f31a74a9f35
# - auth : https://vertexaisearch.cloud.google.com/home/cid/0489ad53-6483-429d-bf46-16a03e59c33b

# %% [markdown]
# ### 2.1.3 별도 계정으로 접속 확인

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.2 Basic role

# %% [markdown]
# ### 2.2.1 외부 계정에 권한 부여

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2.2.2 앱 확인 및 외부 링크 확인

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.3 predefine role

# %% [markdown]
# ### 2.3.1 권한 부여

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 2.3.2 권한, 프로젝트, 외부 접근 확인

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. Drive 권한

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3.1 ALL

# %% [markdown]
# - user A : 개인 drive만 접근 가능
# - user B : 모두 접근 가능

# %% [markdown]
# ### 3.1.1 user A

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3.1.2 user B

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 3.2 Shared drive & folder

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3.2.1 User B

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### 3.2.2 User A

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. Reference

# %% [markdown]
# - https://cloud.google.com/iam/docs/roles-permissions/discoveryengine?hl=ko#discoveryengine.user
