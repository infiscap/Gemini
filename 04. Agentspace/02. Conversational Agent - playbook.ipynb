# %% [markdown]
# # 1. Conversational Agent 이해

# %% [markdown]
# - Goal과 instruction을 활용하는 Playbook과 세부적인 내용으로 구성하는 flow를 이용하여 agent를 만드는 서비스
# - AI Application을 활용한 chat bot 생성
# - Agentspace와 연동 가능

# %% [markdown]
# # 2. playbook을 이용한 agent 만들기

# %% [markdown]
# ## 2.1 환경 설정

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.2 playbook 만들기 - order

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.3 playbook 만들기 - information

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ## 2.4 playbook 수정 - Default Generative Playbook

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 3. 실행하기

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # 4. reference

# %% [markdown]
# - https://cloud.google.com/dialogflow/cx/docs/quick/build-agent-playbook?hl=ko&authuser=8
